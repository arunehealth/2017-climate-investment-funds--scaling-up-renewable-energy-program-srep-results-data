# %% [markdown]
# <a href="https://colab.research.google.com/github/arunehealth/2017-climate-investment-funds--scaling-up-renewable-energy-program-srep-results-data/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4219792-e067-48bd-99d8-bb29645754d1" name="files[]" multiple disabled />
#      <output id="result-e4219792-e067-48bd-99d8-bb29645754d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IDServerData_01102019_v01.csv to IDServerData_01102019_v01.csv

# %%
import io
id = pd.read_csv('IDServerData_01102019_v01.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-796e20c9-0177-4b80-8c03-95fd8e623a14" name="files[]" multiple disabled />
#      <output id="result-796e20c9-0177-4b80-8c03-95fd8e623a14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Eq_ServerData_01012019_v01.csv to Eq_ServerData_01012019_v01.csv

# %%
import io
eq = pd.read_csv('Eq_ServerData_01012019_v01.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bac02e59-1d53-4771-9785-76be84fc9448" name="files[]" multiple disabled />
#      <output id="result-bac02e59-1d53-4771-9785-76be84fc9448">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving infra_ServerData_01102019.csv to infra_ServerData_01102019.csv

# %%
infra = pd.read_csv('infra_ServerData_01102019.csv')

# %%
id.head (1)
# Out:
#   starttime  ...                            meta:instanceID
# 0   44:27.8  ...  uuid:7cb8456e-ce72-4957-aefc-0be90b218a0d
#
# [1 rows x 27 columns]

# %%
eq.head(1)
# Out:
#   starttime  ...                            meta:instanceID
# 0   12:48.9  ...  uuid:9459e577-391f-4fca-8b2c-e3e1eaff2a14
#
# [1 rows x 16 columns]

# %%
infra.head(1)
# Out:
#   starttime  ...                            meta:instanceID
# 0   14:26.9  ...  uuid:1d90babb-6bf8-4c79-b9c7-5b0fa8cf850e
#
# [1 rows x 23 columns]

# %%
pd.merge(id,eq,how='outer',on='site_details:org', left_on=None, right_on=None, left_index=False, right_index=False,sort=False,suffixes=('x','y'))
# Out:
#     starttimex  ...                           meta:instanceIDy
# 0      44:27.8  ...                                        NaN
# 1      23:28.6  ...                                        NaN
# 2      41:28.9  ...                                        NaN
# 3      24:19.9  ...                                        NaN
# 4      42:30.6  ...                                        NaN
# 5      24:07.6  ...                                        NaN
# 6      01:23.9  ...                                        NaN
# 7      21:56.1  ...                                        NaN
# 8      46:44.6  ...                                        NaN
# 9      21:43.1  ...                                        NaN
# 10     35:48.6  ...                                        NaN
# 11     24:12.7  ...                                        NaN
# 12     57:03.0  ...                                        NaN
# 13     53:55.7  ...                                        NaN
# ...

# %%
ideq = pd.merge(id,eq,how='left',on='site_details:org')

# %%
ideq.head(5)
# Out:
#   starttime_x endtime_x  ... additional_comments  meta:instanceID_y
# 0     44:27.8   32:38.3  ...                 NaN                NaN
# 1     23:28.6   31:34.0  ...                 NaN                NaN
# 2     41:28.9   29:41.8  ...                 NaN                NaN
# 3     24:19.9   10:29.5  ...                 NaN                NaN
# 4     42:30.6   09:45.5  ...                 NaN                NaN
#
# [5 rows x 42 columns]

# %%
ideqinfra = pd.merge(ideq,infra,how='outer')

# %%
ideqinfra.head(3)
# Out:
#   starttime_x endtime_x  ... general_pictures  meta:instanceID
# 0     44:27.8   32:38.3  ...              NaN              NaN
# 1     23:28.6   31:34.0  ...              NaN              NaN
# 2     41:28.9   29:41.8  ...              NaN              NaN
#
# [3 rows x 63 columns]
